# %% [markdown]
# # Example annoucement

# %%
press = """
# Press Release

**FOR IMMEDIATE RELEASE**
**NovumTech Global Redefines the Future of Science With a Groundbreaking Discovery in Water Boiling Dynamics**

**Palo Alto, CA — September 5, 2025** — Today, NovumTech Global, the world’s leading pioneer in transformational innovation and next-generation solutions, proudly announced a revolutionary breakthrough in *applied thermal sciences*: for the first time in recorded history, our scientists have *empirically confirmed* that water, under controlled laboratory conditions, consistently boils at 100°C (212°F) at sea level.

This milestone discovery transcends traditional boundaries of knowledge and catapults humanity into a new era of possibility. Leveraging our proprietary *Quantum Hydrothermal Verification Framework™ (QHVF)*, our elite research division spent months validating what many once believed was merely “common knowledge.” The results not only affirm centuries of anecdotal observation but also set the stage for disruptive advancements in industries ranging from culinary innovation to interplanetary habitation.

> “This is more than just science — it’s destiny,” said **Dr. Cassandra Flux**, Chief Science Evangelist at NovumTech Global. “By demonstrating, with unprecedented clarity, the precise boiling point of H₂O, we have effectively rewritten the playbook for how humanity interacts with matter itself.”

The implications of this achievement are limitless:

* **Consumer Applications**: Imagine kettles that heat smarter, faster, and more *intuitively* than ever before.
* **Enterprise Impact**: Industrial food production will be transformed by data-driven precision boiling.
* **Global Scale**: From sustainable agriculture to space exploration, controlled boiling is the keystone of the 21st-century innovation economy.

“Just as the discovery of fire once ignited civilization, today’s announcement sparks the dawn of *Boiling Point 2.0*,” said **Ethan Valor**, CEO of NovumTech Global. “This is not merely about water. This is about harnessing the elemental forces of nature to unlock the boundless potential of tomorrow.”

NovumTech Global remains committed to pushing the frontier of possibility. With our **Boiling Verification Project (BVP)** as a foundation, we will continue to lead the world in re-imagining science for a brighter, hotter, and more *boil-ready* future.

**About NovumTech Global**
NovumTech Global is a global leader in innovation, discovery, and the relentless pursuit of tomorrow. Our mission is to transform the ordinary into the extraordinary through a bold combination of visionary thinking, disruptive science, and industry-leading technology platforms.

**Media Contact**
**Sierra Blaze**
Director of Global Communications
[press@novumtechglobal.com](mailto:press@novumtechglobal.com)

---

Do you want me to also invent **dummy competitors** or “partner organizations” (like *HydraCore Labs* or *Celestia Ventures*) to make the announcement feel even more *corporate drama-laden*?
"""

# %% [markdown]
# # Trying JSONAdapter
# This doesn't work with ollama models

# %%
import dspy
lm = dspy.LM('ollama_chat/qwen3:latest', api_base='http://localhost:11434', api_key='', adapter=dspy.JSONAdapter())
dspy.configure(lm=lm)

# %%
import pydantic
from pydantic import BaseModel

class ScienceNews(pydantic.BaseModel):
    text: str
    scientists_involved: list[str]


class NewsQA(dspy.Signature):
    """Get news about the given science field"""

    science_field: str = dspy.InputField()
    year: int = dspy.InputField()
    num_of_outputs: int = dspy.InputField()
    news: list[ScienceNews] = dspy.OutputField(desc="science news")


predict = dspy.Predict(NewsQA)
predict(science_field="Computer Theory", year=2022, num_of_outputs=1)
dspy.inspect_history()
# Out:
# 2025/09/03 17:20:13 WARNING dspy.adapters.json_adapter: Failed to use structured output format, falling back to JSON mode.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/code/13 - Media AI/media-hub/.venv/lib/python3.13/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:181, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     174 try:
#     175     response = sync_httpx_client.post(
#     176         url=api_base,
#     177         headers=headers,
#     178         data=(
#     179             signed_json_body
#     180             if signed_json_body is not None
# --> 181             else json.dumps(data)
#     182         ),
#     183         timeout=timeout,
#     184         stream=stream,
# ...

# %%
import dspy
lm = dspy.LM('ollama_chat/llama3.3', api_base='http://localhost:11434', api_key='', adapter=dspy.JSONAdapter())
dspy.configure(lm=lm)

# %%
import pydantic
from pydantic import BaseModel

class ScienceNews(pydantic.BaseModel):
    text: str
    scientists_involved: list[str]


class NewsQA(dspy.Signature):
    """Get news about the given science field"""

    science_field: str = dspy.InputField()
    year: int = dspy.InputField()
    num_of_outputs: int = dspy.InputField()
    news: list[ScienceNews] = dspy.OutputField(desc="science news")


predict = dspy.Predict(NewsQA)
predict(science_field="Computer Theory", year=2022, num_of_outputs=1)
dspy.inspect_history()
# Out:
# 2025/09/03 17:22:50 WARNING dspy.adapters.json_adapter: Failed to use structured output format, falling back to JSON mode.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/code/13 - Media AI/media-hub/.venv/lib/python3.13/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:181, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     174 try:
#     175     response = sync_httpx_client.post(
#     176         url=api_base,
#     177         headers=headers,
#     178         data=(
#     179             signed_json_body
#     180             if signed_json_body is not None
# --> 181             else json.dumps(data)
#     182         ),
#     183         timeout=timeout,
#     184         stream=stream,
# ...

# %% [markdown]
# # Attempting BAMLAdapter

# %%
import dspy
from dspy.adapters.baml_adapter import BAMLAdapter

lm = dspy.LM(
    model="ollama/qwen3:latest",
    max_tokens=10000,
    temperature=0.5,
)

dspy.configure(lm=lm, adapter=BAMLAdapter(), track_usage=True)

# %%
import pydantic
from pydantic import BaseModel

class ScienceNews(pydantic.BaseModel):
    text: str
    scientists_involved: list[str]


class NewsQA(dspy.Signature):
    """Get news about the given science field"""

    science_field: str = dspy.InputField()
    year: int = dspy.InputField()
    num_of_outputs: int = dspy.InputField()
    news: list[ScienceNews] = dspy.OutputField(desc="science news")


predict = dspy.Predict(NewsQA)
predict(science_field="Computer Theory", year=2022, num_of_outputs=1)
dspy.inspect_history()
# Out:
# [2025-09-08T21:33:04.765284]
#
# System message:
#
# Your input fields are:
# 1. `science_field` (str):
# 2. `year` (int):
# 3. `num_of_outputs` (int):
# Your output fields are:
# 1. `news` (list):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## science_field ## ]]
# {science_field}
#
# [[ ## year ## ]]
# {year}
#
# [[ ## num_of_outputs ## ]]
# {num_of_outputs}
#
# [[ ## news ## ]]
# Output field `news` should be of type: [
#   {
#     text: string,
#     scientists_involved: string[],
#   }
# ]
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Get news about the given science field
#
#
# User message:
#
# [[ ## science_field ## ]]
# Computer Theory
#
# [[ ## year ## ]]
# 2022
#
# [[ ## num_of_outputs ## ]]
# 1
#
# Respond with a JSON object in the following order of fields: `news` (must be formatted as a valid Python list[ScienceNews]).
#
#
# Response:
#
# ...

# %%
result = predict(science_field="Computer Theory", year=2022, num_of_outputs=1)
result
# Out:
# Prediction(
#     news=[ScienceNews(text='In 2022, significant advancements were made in quantum computing theory, particularly in the development of new algorithms for quantum error correction. Researchers at the University of California, Berkeley, and MIT collaborated to publish groundbreaking work in the field of quantum information theory, which has the potential to revolutionize secure communication and data processing.', scientists_involved=['John Preskill', 'Michael Nielsen'])]
# )

# %%
result.news
# Out:
# [ScienceNews(text='In 2022, significant advancements were made in quantum computing theory, particularly in the development of new algorithms for quantum error correction. Researchers at the University of California, Berkeley, and MIT collaborated to publish groundbreaking work in the field of quantum information theory, which has the potential to revolutionize secure communication and data processing.', scientists_involved=['John Preskill', 'Michael Nielsen'])]

# %%
result.get_lm_usage()
# Out:
# {}

# %%
import time
import dspy

# 1) Use the OpenAI adapter against Ollama's /v1 endpoint
lm = dspy.LM(
    model="openai/qwen3:latest",
    api_base="http://localhost:11434/v1",
    api_key="ollama",           # dummy
    temperature=0.5,
    max_tokens=256,

    # IMPORTANT: don't stream (usage is most reliable non-streaming)
    # If your DSPy/LiteLLM build streams by default, this flag disables it:
    stream=False,               # <- if your DSPy doesn't accept this, just omit it
)

# 2) Disable cache for sure
dspy.configure(lm=lm, track_usage=True, cache=False)

# 3) Use a trivial signature and add a nonce so it's never cached by equality
Ask = dspy.Predict("question -> answer")

res = Ask(question=f"Say hello and include the time {time.time():.0f}")
print("ANSWER:", res.answer)
print("USAGE:", res.get_lm_usage())   # expect {'prompt_tokens': ..., 'completion_tokens': ..., 'total_tokens': ...}
# Out:
# ANSWER: Hello! The time is 1757385771.
# USAGE: {'openai/qwen3:latest': {'completion_tokens': 23, 'prompt_tokens': 149, 'total_tokens': 172, 'completion_tokens_details': None, 'prompt_tokens_details': None}}

# %%
res.get_lm_usage()
# Out:
# {'openai/qwen3:latest': {'completion_tokens': 23,
#   'prompt_tokens': 149,
#   'total_tokens': 172,
#   'completion_tokens_details': None,
#   'prompt_tokens_details': None}}

# %% [markdown]
# # Testing with my past example

# %%
from pydantic import BaseModel, Field
from typing import List, Dict

class ReviewClassification(BaseModel):
    classification: str = Field(..., description = "Topic of the review")
    classification_explanation: str = Field(..., description = "explanation of why the classification rating was given")
    sentiment: int = Field(..., description = "1-5 rating (1 very negative to 5 very positive) for the topic")
    sentiment_explanation: str =  Field(..., description = "explanation of why the sentiment rating was given")

topics = []
template = f"""
You are a expert customer testimonial reviewer who loves to read a customer's review for a given product to identify topics.
Your task is to read a given review: classify the topic and rate the sentiment
"""
customer_review = "As the title says, this is simply the best backpack I've ever used. It's extremely comfortable and sometimes I feel like I forgot to pack my laptop and lunch it's that light. \r\n\r\nMy friends think it's a waste of money (they're not totally wrong) but even when they tried it on they agreed that its simply better than anything they've used. \r\n\r\nI'm a small male who's about 169cm ±2cm and very skinny at 45kg, it's a tad big for me but still fits quite nicely when pulling the adjustable shoulder straps nearly all the way in. \r\n\r\nIt fits exactly a framework laptop, lunch box, pencil case, glasses case, work uniform, whole old backpack, 40oz LTT water bottle, keys and other small things in the front pouch and side pocket. \r\n\r\nThe verdict: if you're just as, if not smaller than me I'd highly recommend waiting for the Yvonne sized one as Linus mentioned a wan or 3 ago (and showed off in the FP exclusive BTS of the AMD upgrade thing Yvonne was in recently) but if you value products that are going to last a long while and you like LTT there simply isn't a better bag for the (albeit quite high) price. (PS Linus I know you read these sometimes and in which case hello!)"
input_text = f""" Given this customer review:
{customer_review}
"""

# %%
import json
from openai import OpenAI

client = OpenAI(
    base_url = 'http://localhost:11434/v1',
    api_key='ollama', # required, but unused
)

json_completion = client.beta.chat.completions.parse(
    model="gemma2:9b-instruct-q8_0",

    response_format= ReviewClassification,
    messages=[
            {"role": "user", "content": template},           
            {"role": "user", "content": input_text},
    ],
    temperature=0.02,
    )
ReviewClassification.model_validate(json_completion.choices[0].message.parsed)

completion = json_completion.to_dict()
print(json.dumps(completion, indent=1))
json_completion.choices[0].message.parsed.model_dump()
# Out:
# {
#  "id": "chatcmpl-773",
#  "choices": [
#   {
#    "finish_reason": "stop",
#    "index": 0,
#    "message": {
#     "content": "{\"classification\": \"Product Review\", \"classification_explanation\": \"The review focuses on the user's experience with a specific backpack, detailing its features, pros, cons, and overall recommendation.\", \"sentiment\": 4, \"sentiment_explanation\": \"The sentiment is overwhelmingly positive. The reviewer uses phrases like 'best backpack I've ever used', 'extremely comfortable', 'simply better than anything they've used', and 'highly recommend'. While acknowledging the price might be high and suggesting a smaller size for certain users, the overall tone is enthusiastic and appreciative.\"} ",
#     "role": "assistant",
#     "tool_calls": null,
#     "parsed": {
#      "classification": "Product Review",
# ...

# %%
# --- deps ---
import dspy
from dspy.adapters.baml_adapter import BAMLAdapter
from pydantic import BaseModel

# ---------- Pydantic schema (for post-validate / typing) ----------
class ReviewClassification(BaseModel):
    classification: str                          # topic
    classification_explanation: str              # why that topic
    sentiment: int                               # 1..5
    sentiment_explanation: str                   # why that sentiment

# ---------- DSPy signature (structured I/O contract) ----------
class ReviewQA(dspy.Signature):
    """You are a expert customer testimonial reviewer who loves to read a customer's review for a given product to identify topics. Your task is to read a given review: classify the topic and rate the sentiment"""
    review: str = dspy.InputField(desc="Customer review text")

    classification: str = dspy.OutputField(desc="Topic of the review")
    classification_explanation: str = dspy.OutputField(desc="explanation of why the classification rating was given")
    sentiment: int = dspy.OutputField(desc="1-5 sentiment score")
    sentiment_explanation: str = dspy.OutputField(desc="Explanation for the sentiment rating")

# ---------- LM config: use OpenAI adapter pointed at Ollama /v1 ----------
lm = dspy.LM(
    model="openai/gemma2:9b-instruct-q8_0",             # use 'openai/*' so usage is populated
    api_base="http://localhost:11434/v1",    # Ollama OpenAI-compatible endpoint
    api_key="ollama",                        # dummy; Ollama ignores it
    temperature=0.02,
    max_tokens=800,
    # If you later enable streaming elsewhere, this helps keep usage attached:
    # stream_options={"include_usage": True},
)

# BAMLAdapter improves structured output reliability
dspy.configure(lm=lm, adapter=BAMLAdapter(), track_usage=True, cache=False)

# ---------- Run ----------
predict = dspy.Predict(ReviewQA)

customer_review = "As the title says, this is simply the best backpack I've ever used. It's extremely comfortable and sometimes I feel like I forgot to pack my laptop and lunch it's that light. \r\n\r\nMy friends think it's a waste of money (they're not totally wrong) but even when they tried it on they agreed that its simply better than anything they've used. \r\n\r\nI'm a small male who's about 169cm ±2cm and very skinny at 45kg, it's a tad big for me but still fits quite nicely when pulling the adjustable shoulder straps nearly all the way in. \r\n\r\nIt fits exactly a framework laptop, lunch box, pencil case, glasses case, work uniform, whole old backpack, 40oz LTT water bottle, keys and other small things in the front pouch and side pocket. \r\n\r\nThe verdict: if you're just as, if not smaller than me I'd highly recommend waiting for the Yvonne sized one as Linus mentioned a wan or 3 ago (and showed off in the FP exclusive BTS of the AMD upgrade thing Yvonne was in recently) but if you value products that are going to last a long while and you like LTT there simply isn't a better bag for the (albeit quite high) price. (PS Linus I know you read these sometimes and in which case hello!)"

res = predict(review=customer_review)

# Structured fields
print("classification:", res.classification)
print("sentiment:", res.sentiment)
print("classification_explanation:", res.classification_explanation[:200], "...")
print("sentiment_explanation:", res.sentiment_explanation[:200], "...")

# Token usage (prompt / completion / total)
print("usage:")
res.get_lm_usage()
# Out:
# classification: Product Review
# sentiment: 5
# classification_explanation: The text focuses on providing a detailed opinion and experience with a specific backpack. ...
# sentiment_explanation: The review expresses overwhelmingly positive sentiment. The user repeatedly uses words like 'best,' 'comfortable,' 'simply better,' and 'highly recommend.' ...
# usage:
# {'openai/gemma2:9b-instruct-q8_0': {'completion_tokens': 76,
#   'prompt_tokens': 581,
#   'total_tokens': 657,
#   'completion_tokens_details': None,
#   'prompt_tokens_details': None}}
